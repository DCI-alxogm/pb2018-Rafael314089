# %%
import scipy.constants as con
import  matplotlib.pyplot as plt
import numpy as np       
import math
archivoDatos = np.loadtxt('IRCF.txt').T
y=archivoDatos[3]
for i in range(np.size(y)):
    if((archivoDatos[1][i]-y[i])<0):
        y[i]=archivoDatos[1][i]

archivoDatos = np.loadtxt('IRCF.txt').T

plt.errorbar(archivoDatos[0], archivoDatos[1], [y,archivoDatos[3]], fmt='o')
plt.ylabel("Intensidad[MJy/sr]")
plt.xlabel("Frecuencia[1/cm]")
plt.grid()
